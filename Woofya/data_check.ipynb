# %%
import pandas as pd

# Load the CSV file
file_path = 'dog_friendly_google_map.csv'
data = pd.read_csv(file_path)

# Display the first few rows to understand the structure of the dataset
data.head(5)
# Out:
#                                              OSrXXb      rllt__details  \
# 0                                          Dogs Bar           ·  · Bar
# 1         Ron Barassi Senior Park Dog Friendly Park         · Dog park
# 2                                   Vincent the Dog          ·  · Cafe
# 3                                               NaN                NaN
# 4  The Tipsy Cow - Cocktail Tapas Bar & Beer Garden  ·  · Cocktail bar
#
#    yi40Hd RDApEe     rllt__details 2 rllt__details 3   rllt__details 4  \
# 0     4.5  (470)              $20–40    St Kilda VIC  ⋅ Opens 5 pm Thu
# 1     4.1   (15)       Docklands VIC             NaN               NaN
# 2     4.4  (292)         Carlton VIC          $20–40      ⋅ Opens 8 am
# 3     NaN    NaN                 NaN             NaN               NaN
# 4     4.7  (310)  Port Melbourne VIC          $20–40  ⋅ Opens 4 pm Wed
#
#   rllt__details 5                                         YQ4gaf src  \
# ...

# %%
len(data['uDyWh'])
# Out:
# 163
